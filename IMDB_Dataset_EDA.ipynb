# %% [markdown]
# <a href="https://colab.research.google.com/github/2001Akhilkatoch/project_on_analysis/blob/main/IMDB_Dataset_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # 1. import python libraries

# %% [markdown]
# **introduction**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
# %matplotlib inline
import seaborn as sns

# %% [markdown]
# # 2. *Upload the Data*

# %% [markdown]
# 📌 Note:
#
# The file.csv contains all the information we need to analyze a bit of everything we know about Netflix and the products within it. It contains 23 unique columns and 3000 rows.
# I create a copy of the dataframe so that I can use and modify it without touching the original file which could always serve as a backup.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df=pd.read_csv('/content/drive/MyDrive/imdb_data.csv')
df.head()
# Out:
#    id                              belongs_to_collection    budget  \
# 0   1  [{'id': 313576, 'name': 'Hot Tub Time Machine ...  14000000
# 1   2  [{'id': 107674, 'name': 'The Princess Diaries ...  40000000
# 2   3                                                NaN   3300000
# 3   4                                                NaN   1200000
# 4   5                                                NaN         0
#
#                                               genres  \
# 0                     [{'id': 35, 'name': 'Comedy'}]
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                      [{'id': 18, 'name': 'Drama'}]
# 3  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
#
#                             homepage    imdb_id original_language  \
# 0                                NaN  tt2637294                en
# 1                                NaN  tt0368933                en
# ...

# %% [markdown]
# * Let's continue our analysis by checking what is the shape of data there are;

# %%
df.shape
# Out:
# (3000, 23)

# %% [markdown]
# * Let's continue our analysis by checking how many columns and names there are;

# %%
df.columns
# Out:
# Index(['id', 'belongs_to_collection', 'budget', 'genres', 'homepage',
#        'imdb_id', 'original_language', 'original_title', 'overview',
#        'popularity', 'poster_path', 'production_companies',
#        'production_countries', 'release_date', 'runtime', 'spoken_languages',
#        'status', 'tagline', 'title', 'Keywords', 'cast', 'crew', 'revenue'],
#       dtype='object')

# %% [markdown]
# 📝 Let's take a look at our dataframe so we can open a few things:
#
# * let's start by observing what types of data we have inside it with the .info () function;

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 23 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3000 non-null   int64
#  1   belongs_to_collection  604 non-null    object
#  2   budget                 3000 non-null   int64
#  3   genres                 2993 non-null   object
#  4   homepage               946 non-null    object
#  5   imdb_id                3000 non-null   object
#  6   original_language      3000 non-null   object
#  7   original_title         3000 non-null   object
#  8   overview               2992 non-null   object
#  9   popularity             3000 non-null   float64
#  10  poster_path            2999 non-null   object
#  11  production_companies   2844 non-null   object
#  12  production_countries   2945 non-null   object
#  13  release_date           3000 non-null   object
# ...

# %% [markdown]
# # ***3. Data Cleaning***

# %% [markdown]
# * Let's continue our analysis by checking if and how many missing values there are;

# %%
df.isnull().sum()
# Out:
# id                          0
# belongs_to_collection    2396
# budget                      0
# genres                      7
# homepage                 2054
# imdb_id                     0
# original_language           0
# original_title              0
# overview                    8
# popularity                  0
# poster_path                 1
# production_companies      156
# production_countries       55
# release_date                0
# runtime                     2
# spoken_languages           20
# status                      0
# tagline                   597
# title                       0
# Keywords                  276
# cast                       13
# crew                       16
# revenue                     0
# dtype: int64

# %% [markdown]
# * As we can see there are many missing values in the various features so I decide to keep the most important columns in my opinion, even if they have different missing values that we will then remove, and to drop other columns that I consider superfluous for the analysis also for the large number of missing values they have;

# %%
df.drop(['belongs_to_collection'],axis=1,inplace=True)
df
# Out:
#         id    budget                                             genres  \
# 0        1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1        2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2        3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3        4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4        5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...    ...       ...                                                ...
# 2995  2996         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2996  2997         0  [{'id': 18, 'name': 'Drama'}, {'id': 10402, 'n...
# 2997  2998  65000000  [{'id': 80, 'name': 'Crime'}, {'id': 28, 'name...
# 2998  2999  42000000  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# 2999  3000  35000000  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...
#
#                                homepage    imdb_id original_language  \
# ...

# %%
df.shape
# Out:
# (3000, 22)

# %% [markdown]
# * Now we can add null value(NaN) to homepage column

# %%
df.loc[:,'homepage']=np.NaN
df
# Out:
# <ipython-input-65-cf31e0e69a49>:1: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:,'homepage']=np.NaN
#         id    budget                                             genres  \
# 0        1  14000000                     [{'id': 35, 'name': 'Comedy'}]
# 1        2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2        3   3300000                      [{'id': 18, 'name': 'Drama'}]
# 3        4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4        5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...    ...       ...                                                ...
# 2995  2996         0  [{'id': 35, 'name': 'Comedy'}, {'id': 10749, '...
# ...

# %%
df.isnull().sum()
# Out:
# id                         0
# budget                     0
# genres                     7
# homepage                3000
# imdb_id                    0
# original_language          0
# original_title             0
# overview                   8
# popularity                 0
# poster_path                1
# production_companies     156
# production_countries      55
# release_date               0
# runtime                    2
# spoken_languages          20
# status                     0
# tagline                  597
# title                      0
# Keywords                 276
# cast                      13
# crew                      16
# revenue                    0
# dtype: int64

# %% [markdown]
# * describe() is used to view some basic statistical details like percentile, mean, std, etc. of a data frame or a series of numeric values.

# %%
df.describe()
# Out:
#                 id        budget  homepage   popularity      runtime  \
# count  3000.000000  3.000000e+03       0.0  3000.000000  2998.000000
# mean   1500.500000  2.253133e+07       NaN     8.463274   107.856571
# std     866.169729  3.702609e+07       NaN    12.104000    22.086434
# min       1.000000  0.000000e+00       NaN     0.000001     0.000000
# 25%     750.750000  0.000000e+00       NaN     4.018053    94.000000
# 50%    1500.500000  8.000000e+06       NaN     7.374861   104.000000
# 75%    2250.250000  2.900000e+07       NaN    10.890983   118.000000
# max    3000.000000  3.800000e+08       NaN   294.337037   338.000000
#
#             revenue
# count  3.000000e+03
# mean   6.672585e+07
# std    1.375323e+08
# min    1.000000e+00
# 25%    2.379808e+06
# 50%    1.680707e+07
# 75%    6.891920e+07
# max    1.519558e+09

# %% [markdown]
# * Finally, let's take a look at our dataframe after the various changes we've made to it.

# %%
df.head()
# Out:
#    id    budget                                             genres  homepage  \
# 0   1  14000000                     [{'id': 35, 'name': 'Comedy'}]       NaN
# 1   2  40000000  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...       NaN
# 2   3   3300000                      [{'id': 18, 'name': 'Drama'}]       NaN
# 3   4   1200000  [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...       NaN
# 4   5         0  [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...       NaN
#
#      imdb_id original_language                            original_title  \
# 0  tt2637294                en                    Hot Tub Time Machine 2
# 1  tt0368933                en  The Princess Diaries 2: Royal Engagement
# 2  tt2582802                en                                  Whiplash
# 3  tt1821480                hi                                   Kahaani
# 4  tt1380152                ko                                      마린보이
#
# ...

# %% [markdown]
# # ***4. Data Analysis and Visualization***

# %% [markdown]
# 1.Which movie have higher profit (mean) as compare to other movies in original languages?

# %%
df['profit']=df['revenue']-df['budget']
df['profit']
# Out:
# 0        -1685349
# 1        55149435
# 2         9792000
# 3        14800000
# 4         3923970
#           ...
# 2995      1596687
# 2996       180590
# 2997     24456761
# 2998    129963386
# 2999     47087155
# Name: profit, Length: 3000, dtype: int64

# %%
x=df[["profit","revenue","budget"]]
x
# Out:
#          profit    revenue    budget
# 0      -1685349   12314651  14000000
# 1      55149435   95149435  40000000
# 2       9792000   13092000   3300000
# 3      14800000   16000000   1200000
# 4       3923970    3923970         0
# ...         ...        ...       ...
# 2995    1596687    1596687         0
# 2996     180590     180590         0
# 2997   24456761   89456761  65000000
# 2998  129963386  171963386  42000000
# 2999   47087155   82087155  35000000
#
# [3000 rows x 3 columns]

# %%
a1=df.groupby(['original_language'])['runtime'].mean()
a1
# Out:
# original_language
# ar     98.000000
# bn    125.000000
# cn    105.450000
# cs     90.000000
# da    105.400000
# de    122.294118
# el     91.000000
# en    106.984078
# es    100.372093
# fa     96.400000
# fi    100.000000
# fr    106.294872
# he     90.000000
# hi    148.880952
# hu    126.000000
# id    150.000000
# it     91.625000
# ja    112.972973
# ko    115.100000
# ml    137.000000
# mr    162.000000
# nb    103.000000
# nl    107.333333
# no     95.500000
# pl     99.000000
# pt    114.666667
# ro    108.750000
# ru     95.586957
# sr     97.000000
# sv    122.375000
# ta    159.875000
# te    146.000000
# tr    119.000000
# ur     94.000000
# vi    135.000000
# zh    121.368421
# Name: runtime, dtype: float64

# %%
# Plotting a bar chart and obtaining the Axes object
ax = a1.plot(kind='bar', x='original_language', y='average_runtime',figsize=(15,9),color="g")

# Setting title, xlabel, and ylabel using the Axes object
ax.set_title("Average Runtime of Original Languages of Movies")
ax.set_xlabel("Original Language")
ax.set_ylabel("Average Runtime")

# Display the plot
plt.show()

# %% [markdown]
# **INFERENCE:**
#
# mr & ta languagse have leading movies runtimes as compare to other movies.

# %% [markdown]
# 2. How many movies released in a year?

# %% [markdown]
# * we can change the format of date-time in dataset so,we can import libraries of datetime.

# %%
from datetime import datetime
from datetime import date

# %%
df['release_date']=pd.to_datetime(df['release_date'])

# %%
df["year"]=df["release_date"].apply(lambda x: x.strftime("%y"))
yearly_movies_release=df.groupby("year")["id"].count()
yearly_movies_release
# Out:
# year
# 00    65
# 01    77
# 02    84
# 03    74
# 04    83
#       ..
# 95    62
# 96    55
# 97    63
# 98    66
# 99    65
# Name: id, Length: 90, dtype: int64

# %%
fig=plt.figure()
fig.set_figheight(5)
fig.set_figwidth(30)
plt.plot(yearly_movies_release,color="r")
plt.xlabel('years')
plt.ylabel('number of released movies')
plt.title("movies released in a particular year")
# Out:
# Text(0.5, 1.0, 'movies released in a particular year')

# %% [markdown]
# **INFERENCE**:
#
# year 2013 are released highest numbet of movies trail by 2012,2014.

# %% [markdown]
# 3.how many movies released in a month?

# %%
df["month"]=df["release_date"].apply(lambda x: x.strftime("%m"))
monthly_movies_release=df.groupby("month")["id"].count()
monthly_movies_release
# Out:
# month
# 01    212
# 02    226
# 03    238
# 04    245
# 05    224
# 06    237
# 07    209
# 08    256
# 09    362
# 10    307
# 11    221
# 12    263
# Name: id, dtype: int64

# %%
plt.plot(monthly_movies_release)
plt.xlabel('months')
plt.ylabel('number of released movies')
plt.title("movies released in a particlar months")
# Out:
# Text(0.5, 1.0, 'movies released in a particlar months')

# %% [markdown]
# INFERENCE:
#
# As we can see or analysis september(09) month releases the (362) highest number of movies.

# %% [markdown]
# 4.what is the profit distribution by each language in a monthly release movies?

# %%
df.groupby(["month","original_language"])['profit'].mean().unstack()
# Out:
# original_language         ar        bn            cn       cs          da  \
# month
# 01                       NaN       NaN  2.609710e+07      NaN         NaN
# 02                       NaN       NaN  5.140264e+07      NaN         NaN
# 03                       NaN       NaN  3.956913e+06  17393.0         NaN
# 04                       NaN       NaN           NaN      NaN   5405313.0
# 05                       NaN       NaN  5.547000e+06      NaN  31570000.0
# 06                       NaN       NaN  1.947200e+05      NaN         NaN
# 07                       NaN       NaN  2.573114e+07      NaN    179943.0
# 08                 1347747.0  536364.0  4.656406e+07      NaN         NaN
# 09                       NaN       NaN  1.107000e+07      NaN   2815105.5
# 10                       NaN       NaN -2.487088e+07      NaN         NaN
# 11                       NaN       NaN  3.960030e+05      NaN         NaN
# 12                       NaN       NaN  3.795182e+07      NaN         NaN
# ...

# %%
a2=df.groupby(["month","original_language"])['profit'].mean().unstack().plot(kind="box",figsize=(15,5))
plt.ylabel('monthly profits in B$')
plt.xlabel('movies_languages')
plt.title("profit distribution by each language")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# **image for understanding the boxplot diagram**

# %% [markdown]
# ![78b14472c4fabf72df1db43f901778be.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# INFERENCE:
#
# This above diagram helps the analysis of the chart of profit distribution by each language.we can see there are lot of ouliers in some languages which indicates the highest or lowest profit.

# %% [markdown]
# 5. Draw the scatter plot of profit of movie which have same release month?

# %%
a3=sorted(df['month'].unique())
a3
# Out:
# ['01', '02', '03', '04', '05', '06', '07', '08', '09', '10', '11', '12']

# %%
a2=df.groupby("month")["profit"].sum()

# %%
plt.scatter(a2,a3)
plt.ylabel('months')
plt.xlabel('profit in B$')
plt.title("monthly released movies profit in billion dollar")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# INFERENCE:
#
# clearly shown the movies which releases in the month of june(06) have highest profit margin as compare to others.

# %% [markdown]
# 5. List out the movies and their genres which genres have most common in movies?

# %%
list_of_all_genres = []
def extract_genre(list_of_genre):
  for genre in list_of_genre:
    list_of_all_genres.append(genre['name'])

# %%
def convert_list(l1):
  return eval(l1)

# %%
df.loc[~df['genres'].isna(), 'genres'] = df.loc[~df['genres'].isna(), 'genres'].apply(convert_list)

# %%
df_genre = df[~df['genres'].isna()]
df_genre[['title','genres']]
# Out:
#                                          title  \
# 0                       Hot Tub Time Machine 2
# 1     The Princess Diaries 2: Royal Engagement
# 2                                     Whiplash
# 3                                      Kahaani
# 4                                   Marine Boy
# ...                                        ...
# 2995                                   Chasers
# 2996                          We Are the Best!
# 2997                   The Long Kiss Goodnight
# 2998                          Along Came Polly
# 2999                                 Abduction
#
#                                                  genres
# 0                        [{'id': 35, 'name': 'Comedy'}]
# 1     [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 2                         [{'id': 18, 'name': 'Drama'}]
# 3     [{'id': 53, 'name': 'Thriller'}, {'id': 18, 'n...
# 4     [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...
# ...                                                 ...
# ...

# %%
df_genre['genres'].apply(extract_genre)
# Out:
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
#         ...
# 2995    None
# 2996    None
# 2997    None
# 2998    None
# 2999    None
# Name: genres, Length: 2993, dtype: object

# %%
set(list_of_all_genres)
# Out:
# {'Action',
#  'Adventure',
#  'Animation',
#  'Comedy',
#  'Crime',
#  'Documentary',
#  'Drama',
#  'Family',
#  'Fantasy',
#  'Foreign',
#  'History',
#  'Horror',
#  'Music',
#  'Mystery',
#  'Romance',
#  'Science Fiction',
#  'TV Movie',
#  'Thriller',
#  'War',
#  'Western'}

# %%
plt.figure(figsize=(20, 5))
plt.hist(list_of_all_genres)
plt.xlabel('genres')
plt.ylabel('frequency')
plt.title("frequency of genres")
# Out:
# Text(0.5, 1.0, 'frequency of genres')

# %% [markdown]
# INFERENCE:
#
# comedy and drama genres have highest frequency in around 2600 movies.

# %% [markdown]
# 7. Find the correlation between numerical values like profit,budget,revenue?

# %% [markdown]
# * we can the graphs of time series,value,distribution.

# %%
 total_capital_df = df[["profit","revenue","budget"]]
 corr_df =  total_capital_df.corr()
 corr_df
# Out:
#            profit   revenue    budget
# profit   1.000000  0.976191  0.592294
# revenue  0.976191  1.000000  0.752965
# budget   0.592294  0.752965  1.000000
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = value_plot(corr_df, *['profit'], **{})
# chart
# import numpy as np
# from google.colab import autoviz
#
# def value_plot(df, y, figscale=1):
#   from matplotlib import pyplot as plt
#   df[y].plot(kind='line', figsize=(8 * figscale, 4 * figscale), title=y)
#   plt.gca().spines[['top', 'right']].set_visible(False)
#   plt.tight_layout()
# ...

# %% [markdown]
# *  *Heat map defines the correlatioon of numerical values*

# %%
sns.heatmap( corr_df)
# Out:
# <Axes: >

# %% [markdown]
#  **Thank you for looking at the analysis, hit me up if there's anything you'd like me to discover!**
